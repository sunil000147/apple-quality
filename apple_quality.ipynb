# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('/content/apple_quality.csv')
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4001 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
df.columns
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %% [markdown]
# **variable description**
#
#
# 1. **A_id**:
#    - This variable likely represents a unique identifier or code assigned to each apple sample
#
# 2. **Size**:
#    - Size refers to the physical dimensions of the apple, usually measured in terms of diameter or circumference.
#
# 3. **Weight**:
#    - Weight indicates the mass of the apple, measured in grams or ounces.
#
# 4. **Sweetness**:
#    - Sweetness refers to the level of natural sugars present in the apple, which contributes to its taste profile.
#
# 5. **Crunchiness**:
#    - Crunchiness describes the texture of the apple when it's bitten into or chewed.
# 6. **Juiciness**:
#    - Juiciness represents the amount of moisture or juice content within the apple flesh.
#
# 7. **Ripeness**:
#    - Ripeness indicates the stage of maturity of the apple, ranging from unripe to fully ripe.
# 8. **Acidity**:
#    - Acidity refers to the level of acidity or tartness present in the apple.
#
# 9. **Quality**:
#    - Quality is a subjective measure. And it has two values

# %%
df.isna().sum()
# Out:
# A_id           1
# Size           1
# Weight         1
# Sweetness      1
# Crunchiness    1
# Juiciness      1
# Ripeness       1
# Acidity        0
# Quality        1
# dtype: int64

# %%
df[df['Size'].isna()]
# Out:
#       A_id  Size  Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 4000   NaN   NaN     NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 4000  Created_by_Nidula_Elgiriyewithana     NaN

# %%
df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
df.nunique()
# Out:
# A_id           4000
# Size           4000
# Weight         4000
# Sweetness      4000
# Crunchiness    4000
# Juiciness      4000
# Ripeness       4000
# Acidity        4001
# Quality           2
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                A_id         Size       Weight    Sweetness  Crunchiness  \
# count   4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean    1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std     1154.844867     1.928059     1.602507     1.943441     1.402757
# min        0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%      999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%     1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%     2999.250000     0.805526     0.030976     0.801922     1.894234
# max     3999.000000     6.406367     5.790714     6.374916     7.619852
#
#           Juiciness     Ripeness       Acidity Quality
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# ...

# %%
df['Acidity']= pd.to_numeric(df['Acidity'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4000 non-null   float64
#  8   Quality      4000 non-null   object
# dtypes: float64(8), object(1)
# memory usage: 312.5+ KB

# %%
for i in df.columns:
  plt.title(i)
  sns.histplot(df[i],kde=True)
  plt.show()
  print()

# %% [markdown]
# #finding correlation

# %%
plt.title('correaltion heatmap of df')
sns.heatmap(df.corr(),annot=True,cmap='BuPu')
plt.show()
# Out:
# <ipython-input-48-023b226bc301>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='BuPu')

# %% [markdown]
# **There is no multi-collinearity in the dataset**

# %% [markdown]
# # Checking for outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for i in df.columns:
  sns.boxplot(df[i])
  plt.title(i)
  plt.show()

# %%
df.columns
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
def outlier_handling(column):

  lower_fence=np.quantile(column,0.10)
  print('lower_fence=',lower_fence)
  higher_fence=np.quantile(column,0.90)
  print('higher_fence=',higher_fence)
  outliers=[]
  for i in column:
    if i>higher_fence or i<lower_fence:
      outliers.append(i)
  print('number of outliers=',len(outliers))
  print()

# %%
for i in df[['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
       'Ripeness', 'Acidity']]:
  print(i)
  outlier_handling(df[i])
# Out:
# Size
# lower_fence= -2.9737977606
# higher_fence= 1.9705677940999995
# number of outliers= 800
#
# Weight
# lower_fence= -3.0198968882
# higher_fence= 0.9986928595999996
# number of outliers= 800
#
# Sweetness
# lower_fence= -2.9300390267
# higher_fence= 2.0770873489999997
# number of outliers= 800
#
# Crunchiness
# lower_fence= -0.7716474637999999
# higher_fence= 2.7270518908999994
# number of outliers= 800
#
# Juiciness
# lower_fence= -1.9616028506999998
# higher_fence= 2.9426539098999998
# number of outliers= 800
#
# Ripeness
# lower_fence= -1.9184021701999998
# higher_fence= 2.8985221776999994
# number of outliers= 800
#
# Acidity
# lower_fence= -2.6203169675
# higher_fence= 2.7482733684999996
# number of outliers= 800

# %% [markdown]
# #feature scaling

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
x=df.drop(columns=['A_id','Quality'])
x=ss.fit_transform(x)
x
# Out:
# array([[-1.79842417, -0.95037339,  2.99342063, ...,  0.69054495,
#         -0.08987211, -0.26941526],
#        [-0.35906018, -1.15440431,  2.12769769, ...,  0.17676683,
#          0.1970196 , -0.37899737],
#        [ 0.1094454 , -0.22575916, -0.65250727, ...,  1.20542179,
#         -0.28615565,  1.20604367],
#        ...,
#        [-1.1056547 , -0.71690397, -1.01378401, ...,  0.87437918,
#          2.27595716, -0.66895013],
#        [-1.81811235, -0.49290842,  1.45990059, ...,  0.85454883,
#         -0.15141937, -1.09317096],
#        [ 0.40540882, -0.45307081,  0.30449592, ...,  0.39095445,
#         -0.68021237,  0.72176064]])

# %%
df['Quality'].value_counts()
# Out:
# good    2004
# bad     1996
# Name: Quality, dtype: int64

# %%
plt.title('countplot of quality')
sns.countplot(df['Quality'])
plt.show()

# %% [markdown]
# **the dataset is balanced**

# %%
y=np.where(df['Quality']=='good',1,0)
y
# Out:
# array([1, 1, 0, ..., 0, 1, 1])

# %% [markdown]
# #modelling

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=3)

# %%
x_train
# Out:
# array([[-0.8535156 , -0.54871977,  1.54778105, ...,  0.45870146,
#          0.14971376, -0.11772105],
#        [ 1.71759154, -0.00654133, -0.47735069, ...,  1.26031457,
#         -0.58967398,  0.70331732],
#        [ 0.30191295, -0.56465858,  0.91236367, ...,  0.05969007,
#          0.75198851, -0.34089386],
#        ...,
#        [-0.78578371,  0.30237268,  0.76134305, ...,  0.97349255,
#         -1.69475835,  1.67699202],
#        [ 0.86148834, -1.54716971, -0.71327934, ..., -0.54795288,
#         -0.32980854, -0.63667946],
#        [-0.29109415,  0.65225419, -0.20084339, ..., -1.99576758,
#          0.21861114,  0.88461441]])

# %%
y_train
# Out:
# array([1, 1, 1, ..., 0, 1, 0])

# %%
# !pip install LightGBM

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.svm import  SVC
from sklearn.linear_model import LogisticRegression

# %%
dtc=DecisionTreeClassifier()
rfc=RandomForestClassifier()
xgb=XGBClassifier()
lgbm=LGBMClassifier()
svc=SVC()
lr=LogisticRegression()

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()

# %%
from sklearn.metrics import accuracy_score,classification_report,f1_score

# %%
def modeling(model,x_train,y_train):
  model.fit(x_train,y_train)

  y_pred=model.predict(x_test)
  accuracy=accuracy_score(y_test,y_pred)
  print('accuracy_score=',accuracy)
  print('classification_report=\n',classification_report(y_test,y_pred))

# %%
modeling(dtc,x_train,y_train)
# Out:
# accuracy_score= 0.79
# classification_report=
#                precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79       492
#            1       0.79      0.79      0.79       508
#
#     accuracy                           0.79      1000
#    macro avg       0.79      0.79      0.79      1000
# weighted avg       0.79      0.79      0.79      1000
#
# f1 score= 0.7933070866141733

# %%
modeling(rfc,x_train,y_train)
# Out:
# accuracy_score= 0.892
# classification_report=               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89       492
#            1       0.88      0.91      0.89       508
#
#     accuracy                           0.89      1000
#    macro avg       0.89      0.89      0.89      1000
# weighted avg       0.89      0.89      0.89      1000
#
# f1 score= 0.8949416342412451

# %%
modeling(xgb,x_train,y_train)
# Out:
# accuracy_score= 0.906
# classification_report=               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90       492
#            1       0.90      0.91      0.91       508
#
#     accuracy                           0.91      1000
#    macro avg       0.91      0.91      0.91      1000
# weighted avg       0.91      0.91      0.91      1000
#
# f1 score= 0.9078431372549018

# %%
modeling(lgbm,x_train,y_train)
# Out:
# [LightGBM] [Info] Number of positive: 1496, number of negative: 1504
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000375 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1785
# [LightGBM] [Info] Number of data points in the train set: 3000, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498667 -> initscore=-0.005333
# [LightGBM] [Info] Start training from score -0.005333
# accuracy_score= 0.906
# classification_report=               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90       492
#            1       0.90      0.91      0.91       508
#
#     accuracy                           0.91      1000
#    macro avg       0.91      0.91      0.91      1000
# weighted avg       0.91      0.91      0.91      1000
#
# f1 score= 0.9078431372549018

# %%
modeling(svc,x_train,y_train)
# Out:
# accuracy_score= 0.902
# classification_report=               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       492
#            1       0.89      0.92      0.90       508
#
#     accuracy                           0.90      1000
#    macro avg       0.90      0.90      0.90      1000
# weighted avg       0.90      0.90      0.90      1000
#
# f1 score= 0.9046692607003891

# %%
modeling(lr,x_train,y_train)
# Out:
# accuracy_score= 0.753
# classification_report=               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75       492
#            1       0.76      0.75      0.76       508
#
#     accuracy                           0.75      1000
#    macro avg       0.75      0.75      0.75      1000
# weighted avg       0.75      0.75      0.75      1000
#
# f1 score= 0.7561697926949654

# %%
modeling(nb,x_train,y_train)
# Out:
# accuracy_score= 0.75
# classification_report=               precision    recall  f1-score   support
#
#            0       0.73      0.77      0.75       492
#            1       0.77      0.73      0.75       508
#
#     accuracy                           0.75      1000
#    macro avg       0.75      0.75      0.75      1000
# weighted avg       0.75      0.75      0.75      1000
#
# f1 score= 0.747983870967742
